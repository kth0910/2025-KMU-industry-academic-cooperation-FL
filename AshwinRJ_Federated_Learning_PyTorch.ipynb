# %% [markdown]
# <a href="https://colab.research.google.com/github/kth0910/2025-KMU-industry-academic-cooperation-FL/blob/main/AshwinRJ_Federated_Learning_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd "/content/drive/My Drive/"

# %%
# !git clone https://github.com/AshwinRJ/Federated-Learning-PyTorch.git
# Out:
# Cloning into 'Federated-Learning-PyTorch'...
# remote: Enumerating objects: 261, done.
# remote: Total 261 (delta 0), reused 0 (delta 0), pack-reused 261 (from 1)
# Receiving objects: 100% (261/261), 214.52 KiB | 21.45 MiB/s, done.
# Resolving deltas: 100% (136/136), done.

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
# !pip install -r Federated-Learning-PyTorch/requirments.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 15.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.17.1 requires protobuf<6.0.0,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# yfinance 0.2.59 requires protobuf<6,>=5.29.0, but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
import torch
import torchvision
import numpy
import matplotlib

print("torch version : ", torch.__version__)
print("torchvision version : ", torchvision.__version__)
print("numpy version : ", numpy.__version__)
print("matplotlib version : ", matplotlib.__version__)
# Out:
# torch version :  2.6.0+cu124
# torchvision version :  0.21.0+cu124
# numpy version :  2.0.2
# matplotlib version :  3.10.0

# %%
# !python Federated-Learning-PyTorch/src/baseline_main.py --model=mlp --dataset=mnist --gpu=0 --epochs=10
# Out:
# 100% 9.91M/9.91M [00:00<00:00, 12.9MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 335kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 2.76MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 19.6MB/s]
# MLP(
#   (layer_input): Linear(in_features=784, out_features=64, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (layer_hidden): Linear(in_features=64, out_features=10, bias=True)
#   (softmax): Softmax(dim=1)
# )
#   0% 0/10 [00:00<?, ?it/s]Train Epoch: 1 [0/60000 (0%)]	Loss: -0.102505
# Train Epoch: 1 [3200/60000 (5%)]	Loss: -0.115613
# Train Epoch: 1 [6400/60000 (11%)]	Loss: -0.153616
# Train Epoch: 1 [9600/60000 (16%)]	Loss: -0.266881
# Train Epoch: 1 [12800/60000 (21%)]	Loss: -0.309441
# Train Epoch: 1 [16000/60000 (27%)]	Loss: -0.361949
# Train Epoch: 1 [19200/60000 (32%)]	Loss: -0.446632
# Train Epoch: 1 [22400/60000 (37%)]	Loss: -0.405578
# Train Epoch: 1 [25600/60000 (43%)]	Loss: -0.444961
# Train Epoch: 1 [28800/60000 (48%)]	Loss: -0.533814
# ...

# %%
# !python Federated-Learning-PyTorch/src/federated_main.py --model=mlp --dataset=mnist --gpu=0 --epochs=10 --iid=1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# | Global Round : 0 | Local Epoch : 1 | [400/480 (83%)]	Loss: -0.207755
# | Global Round : 0 | Local Epoch : 2 | [0/480 (0%)]	Loss: -0.215934
# | Global Round : 0 | Local Epoch : 2 | [100/480 (21%)]	Loss: -0.113260
# | Global Round : 0 | Local Epoch : 2 | [200/480 (42%)]	Loss: -0.295349
# | Global Round : 0 | Local Epoch : 2 | [300/480 (62%)]	Loss: -0.148775
# | Global Round : 0 | Local Epoch : 2 | [400/480 (83%)]	Loss: -0.347356
# | Global Round : 0 | Local Epoch : 3 | [0/480 (0%)]	Loss: -0.251657
# | Global Round : 0 | Local Epoch : 3 | [100/480 (21%)]	Loss: -0.265835
# | Global Round : 0 | Local Epoch : 3 | [200/480 (42%)]	Loss: -0.153249
# | Global Round : 0 | Local Epoch : 3 | [300/480 (62%)]	Loss: -0.256329
# | Global Round : 0 | Local Epoch : 3 | [400/480 (83%)]	Loss: -0.226995
# | Global Round : 0 | Local Epoch : 4 | [0/480 (0%)]	Loss: -0.371713
# | Global Round : 0 | Local Epoch : 4 | [100/480 (21%)]	Loss: -0.208866
# ...

# %%
# !python Federated-Learning-PyTorch/src/federated_main.py --model=mlp --dataset=mnist --gpu=0 --epochs=10 --iid=0
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# | Global Round : 0 | Local Epoch : 1 | [400/480 (83%)]	Loss: -0.916982
# | Global Round : 0 | Local Epoch : 2 | [0/480 (0%)]	Loss: -0.894571
# | Global Round : 0 | Local Epoch : 2 | [100/480 (21%)]	Loss: -0.937653
# | Global Round : 0 | Local Epoch : 2 | [200/480 (42%)]	Loss: -0.905717
# | Global Round : 0 | Local Epoch : 2 | [300/480 (62%)]	Loss: -0.964610
# | Global Round : 0 | Local Epoch : 2 | [400/480 (83%)]	Loss: -0.974997
# | Global Round : 0 | Local Epoch : 3 | [0/480 (0%)]	Loss: -0.984682
# | Global Round : 0 | Local Epoch : 3 | [100/480 (21%)]	Loss: -0.959632
# | Global Round : 0 | Local Epoch : 3 | [200/480 (42%)]	Loss: -0.991278
# | Global Round : 0 | Local Epoch : 3 | [300/480 (62%)]	Loss: -0.945735
# | Global Round : 0 | Local Epoch : 3 | [400/480 (83%)]	Loss: -0.954554
# | Global Round : 0 | Local Epoch : 4 | [0/480 (0%)]	Loss: -0.957173
# | Global Round : 0 | Local Epoch : 4 | [100/480 (21%)]	Loss: -0.995677
# ...

# %%
# !python Federated-Learning-PyTorch/src/federated_main.py --model=mlp --dataset=mnist --gpu=0 --epochs=4 --iid=0 --frac=0.5
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# | Global Round : 2 | Local Epoch : 3 | [0/480 (0%)]	Loss: -0.960128
# | Global Round : 2 | Local Epoch : 3 | [100/480 (21%)]	Loss: -0.993895
# | Global Round : 2 | Local Epoch : 3 | [200/480 (42%)]	Loss: -0.989118
# | Global Round : 2 | Local Epoch : 3 | [300/480 (62%)]	Loss: -0.996261
# | Global Round : 2 | Local Epoch : 3 | [400/480 (83%)]	Loss: -0.925882
# | Global Round : 2 | Local Epoch : 4 | [0/480 (0%)]	Loss: -0.998727
# | Global Round : 2 | Local Epoch : 4 | [100/480 (21%)]	Loss: -0.996116
# | Global Round : 2 | Local Epoch : 4 | [200/480 (42%)]	Loss: -0.996949
# | Global Round : 2 | Local Epoch : 4 | [300/480 (62%)]	Loss: -0.984988
# | Global Round : 2 | Local Epoch : 4 | [400/480 (83%)]	Loss: -0.999319
# | Global Round : 2 | Local Epoch : 5 | [0/480 (0%)]	Loss: -0.978122
# | Global Round : 2 | Local Epoch : 5 | [100/480 (21%)]	Loss: -0.989911
# | Global Round : 2 | Local Epoch : 5 | [200/480 (42%)]	Loss: -0.990287
# ...

# %%
# !python Federated-Learning-PyTorch/src/federated_main.py --model=mlp --dataset=mnist --gpu=0 --epochs=5 --iid=0 --frac=0.8 --local_ep=2
# Out:
# Experimental details:
#     Model     : mlp
#     Optimizer : sgd
#     Learning  : 0.01
#     Global Rounds   : 5
#
#     Federated parameters:
#     Non-IID
#     Fraction of users  : 0.8
#     Local Batch size   : 10
#     Local Epochs       : 2
#
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/mnist.py:66: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# MLP(
#   (layer_input): Linear(in_features=784, out_features=64, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (layer_hidden): Linear(in_features=64, out_features=10, bias=True)
#   (softmax): Softmax(dim=1)
# )
#   0% 0/5 [00:00<?, ?it/s]
#  | Global Training Round : 1 |
#
# ...
